# %% [markdown]
# # EDBSCAM-ICR Parameter Tunning ymusic

# %%
#imports
import numpy as np 
import csv
import pandas as pd
import re
import sys
import math
import matplotlib.pyplot as plt
from numpy import linalg as LA
import random
from sklearn.preprocessing import normalize
from numba import njit
from collections import defaultdict
import random
from implicit_data import ImplicitData
import numpy as np
from BISGD import BISGD
from EDBSCAM_ICR import EDBSCAM_ICR
from collections import defaultdict
from eval_implicit import EvalPrequential
from datetime import datetime
import getopt

# %% [markdown]
# ## Functions

# %%
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

def sumvector(V,x):
    result = []
    for v in V:
        temp = v + x
        result.append(temp)
    return result    

def multvector(x,V):
    result = []
    for v in V:
        temp = v * x
        result.append(temp)
    return result    

def TransformVec(V):
  
    for i in range(len(V)):
        V[i] = sigmoid(V[i])
    D = LA.norm(V)
    D=1/D
    new = D * V
  

    return new

# %% [markdown]
# ## Get the data

# %%
sys.path.append('./')
configPath = 'config'
dataPath = 'ymusic_gte90_6kusers.tsv'


Data = []
data = pd.read_csv("ymusic_sample5_1.csv")
print(data)
Data = data.values.tolist()   
Data = Data[:1000]
# Out:
#        Unnamed: 0  user_id  item_id
# 0            3873   795245    10843
# 1            3874   795245    56437
# 2            3875   795245    75757
# 3            3876   795245    96467
# 4            3877   795245   111214
# ...           ...      ...      ...
# 22775      476510   555020   475132
# 22776      476511   555020   141032
# 22777      476512   555020   201436
# 22778      476513   555020   125269
# 22779      476514   555020   141393
#
# [22780 rows x 3 columns]

# %% [markdown]
# # Parameter Study

# %% [markdown]
# ## Eps

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


eps_array = [0.1,0.25,0.5,0.75,1.0]
num_clusters = 8
cl_num_iterations = 5
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 200
num_iter = 9
learn_rate = 0.25
regularization = 0.45
#eps = 0.4
MinPts = 5
k = 8
for ep in eps_array:
    print("eps:")
    print(ep)
    model = EDBSCAM_ICR(ImplicitData([],[]),  ep, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# eps:
# 0.1
# start time 2022-09-16 11:20:12.910466
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[719230, 34525], [719230, 5980], [719230, 12563], [719230, 21244], [719230, 25311]]
# 5
# -----------------
#
# Cluster2
#
# Cluster2 Points:
# -----------------
# [[431811, 17014], [431811, 5980], [431811, 9101], [431811, 11059], [431811, 12563]]
# 5
# -----------------
#
# Cluster3
#
# Cluster3 Points:
# -----------------
# [[701787, 175835], [701787, 9101], [701787, 40458], [701787, 47528], [701787, 146781]]
# 5
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[497305, 140753], [497305, 18545], [497305, 40476], [497305, 56437], [497305, 96319]]
# 5
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[665714, 55629], [665714, 10843], [665714, 17014], [665714, 21244], [665714, 40476]]
# 5
# -----------------
#
# Cluster6
#
# Cluster6 Points:
# -----------------
# [[369049, 520381], [369049, 68496], [369049, 180037], [369049, 192496], [369049, 212016]]
# 5
# -----------------
#
# Cluster7
#
# Cluster7 Points:
# -----------------
# [[69450, 56437], [69450, 5980], [69450, 9101], [69450, 12563], [69450, 21244]]
# 5
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[656429, 97508], [656429, 302761], [656429, 144592], [656429, 4283], [656429, 17863]]
# 5
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[532699, 56437], [532699, 5980], [532699, 9101], [532699, 12563], [532699, 40458]]
# 5
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[887491, 96467], [887491, 34525], [887491, 40476], [887491, 56437], [887491, 96319]]
# 5
# -----------------
# npmean(resuls[Recall@20]) 0.25
# end time 2022-09-16 11:40:47.018599
# run time 0:20:34.108133
#
# get tuple 3.929543495178223e-06
# recommend 0.05015534162521362
# eval_point 4.084904988606771e-05
# update 0.12334171495437622
# eps:
# 0.25
# start time 2022-09-16 11:40:47.185134
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[719230, 34525], [719230, 5980], [719230, 12563], [719230, 21244], [719230, 25311]]
# 5
# -----------------
#
# Cluster2
#
# Cluster2 Points:
# -----------------
# [[431811, 17014], [431811, 5980], [431811, 9101], [431811, 11059], [431811, 12563]]
# 5
# -----------------
#
# Cluster3
#
# Cluster3 Points:
# -----------------
# [[701787, 175835], [701787, 9101], [701787, 40458], [701787, 47528], [701787, 146781]]
# 5
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[497305, 140753], [497305, 18545], [497305, 40476], [497305, 56437], [497305, 96319]]
# 5
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[665714, 55629], [665714, 10843], [665714, 17014], [665714, 21244], [665714, 40476]]
# 5
# -----------------
#
# Cluster6
#
# Cluster6 Points:
# -----------------
# [[369049, 520381], [369049, 68496], [369049, 180037], [369049, 192496], [369049, 212016]]
# 5
# -----------------
#
# Cluster7
#
# Cluster7 Points:
# -----------------
# [[69450, 56437], [69450, 5980], [69450, 9101], [69450, 12563], [69450, 21244]]
# 5
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[656429, 97508], [656429, 302761], [656429, 144592], [656429, 4283], [656429, 17863]]
# 5
# -----------------
#
# Cluster7
#
# Cluster7 Points:
# -----------------
# [[532699, 56437], [532699, 5980], [532699, 9101], [532699, 12563], [532699, 40458]]
# 5
# -----------------
#
# Cluster7
#
# Cluster7 Points:
# -----------------
# [[887491, 96467], [887491, 34525], [887491, 40476], [887491, 56437], [887491, 96319]]
# 5
# -----------------
#
# Cluster7
#
411, 131367], [704411, 180037], [704411, 215524], [704411, 248089], [704411, 267723], [704411, 303578], [704411, 344617], [704411, 405897], [704411, 434897], [704411, 492607], [431811, 5980], [431811, 9101], [431811, 11059], [431811, 12563], [431811, 17014], [431811, 18879], [431811, 37625], [431811, 40458], [431811, 68496], [431811, 74968], [431811, 126535], [431811, 129462], [431811, 146781], [431811, 175835], [431811, 189820], [431811, 192496], [431811, 194044], [431811, 198219], [431811, 212016], [431811, 230673], [431811, 238557], [431811, 239762], [431811, 297989], [431811, 349250], [431811, 350511], [431811, 452599], [431811, 482069], [431811, 489371], [719230, 5980], [719230, 12563], [719230, 21244], [719230, 25311], [719230, 34525], [719230, 40476], [719230, 51137], [719230, 68496], [719230, 117158], [719230, 129462], [719230, 169708], [719230, 183450], [719230, 192496], [719230, 194044], [719230, 196852], [719230, 206975], [719230, 212016], [719230, 213829], [719230, 230673], [719230, 297989], [719230, 349250], [719230, 357972], [719230, 371598], [719230, 376940], [719230, 434897], [665714, 10843], [665714, 17014], [665714, 21244], [665714, 40476], [665714, 55629], [665714, 67176], [665714, 117158], [665714, 1631 ...
# 1130
# -----------------
# npmean(resuls[Recall@20]) 0.125
# end time 2022-09-16 12:51:33.029528
# run time 0:23:11.354837
#
# get tuple 3.6062002182006837e-06
# recommend 0.054285287857055664
# eval_point 3.5762786865234375e-05
# update 0.13908305180072783
# eps:
# 1.0
# start time 2022-09-16 12:51:36.463923
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 13:14:30.181603
# run time 0:22:53.717680
#
# get tuple 3.68807315826416e-06
# recommend 0.07316970825195312
# eval_point 3.7125178745814734e-05
# update 0.1373115475177765

# %% [markdown]
# ## MinPts

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


min_array = [5,10,15,20,2.5,30]

num_clusters = 8
cl_num_iterations = 5
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 200
num_iter = 9
learn_rate = 0.25
regularization = 0.45
eps = 0.1
k = 8
for min in min_array:
    print("min:")
    print(min)
    model = EDBSCAM_ICR(ImplicitData([],[]),  eps, min, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# min:
# 5
# start time 2022-09-16 14:57:28.206184
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[719230, 34525], [719230, 5980], [719230, 12563], [719230, 21244], [719230, 25311]]
# 5
# -----------------
#
# Cluster2
#
# Cluster2 Points:
# -----------------
# [[431811, 17014], [431811, 5980], [431811, 9101], [431811, 11059], [431811, 12563]]
# 5
# -----------------
#
# Cluster3
#
# Cluster3 Points:
# -----------------
# [[701787, 175835], [701787, 9101], [701787, 40458], [701787, 47528], [701787, 146781]]
# 5
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[497305, 140753], [497305, 18545], [497305, 40476], [497305, 56437], [497305, 96319]]
# 5
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[665714, 55629], [665714, 10843], [665714, 17014], [665714, 21244], [665714, 40476]]
# 5
# -----------------
#
# Cluster6
#
# Cluster6 Points:
# -----------------
# [[369049, 520381], [369049, 68496], [369049, 180037], [369049, 192496], [369049, 212016]]
# 5
# -----------------
#
# Cluster7
#
# Cluster7 Points:
# -----------------
# [[69450, 56437], [69450, 5980], [69450, 9101], [69450, 12563], [69450, 21244]]
# 5
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[656429, 97508], [656429, 302761], [656429, 144592], [656429, 4283], [656429, 17863]]
# 5
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[532699, 56437], [532699, 5980], [532699, 9101], [532699, 12563], [532699, 40458]]
# 5
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[887491, 96467], [887491, 34525], [887491, 40476], [887491, 56437], [887491, 96319]]
# 5
# -----------------
# npmean(resuls[Recall@20]) 0.07142857142857142
# end time 2022-09-16 15:18:55.568450
# run time 0:21:27.362266
#
# get tuple 4.318332672119141e-06
# recommend 0.0636460610798427
# eval_point 4.1757311139787945e-05
# update 0.12863744456768036
# min:
# 10
# start time 2022-09-16 15:18:55.734477
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[719230, 129462], [719230, 5980], [719230, 12563], [719230, 21244], [719230, 25311], [719230, 34525], [719230, 40476], [719230, 51137], [719230, 68496], [719230, 117158]]
# 10
# -----------------
#
# Cluster2
#
# Cluster2 Points:
# -----------------
# [[431811, 74968], [431811, 5980], [431811, 9101], [431811, 11059], [431811, 12563], [431811, 17014], [431811, 18879], [431811, 37625], [431811, 40458], [431811, 68496]]
# 10
# -----------------
# npmean(resuls[Recall@20]) 0.14285714285714285
# end time 2022-09-16 15:40:01.515658
# run time 0:21:05.781181
#
# get tuple 4.156351089477539e-06
# recommend 0.07465888772691999
# eval_point 4.82457024710519e-05
# update 0.12646422863006593
# min:
# 15
# start time 2022-09-16 15:40:01.684463
# npmean(resuls[Recall@20]) 0.1111111111111111
# end time 2022-09-16 16:00:30.909724
# run time 0:20:29.225261
#
# get tuple 4.224896430969239e-06
# recommend 0.06392256418863933
# eval_point 4.288885328504774e-05
# update 0.12285626287460327
# min:
# 20
# start time 2022-09-16 16:00:31.074830
# npmean(resuls[Recall@20]) 0.2727272727272727
# end time 2022-09-16 16:20:42.834427
# run time 0:20:11.759597
#
# get tuple 4.278373718261719e-06
# recommend 0.047759836370294746
# eval_point 4.313208840110085e-05
# update 0.12111404273509979
# min:
# 2.5
# start time 2022-09-16 16:20:42.968385
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[719230, 21244], [719230, 5980], [719230, 12563]]
# 3
# -----------------
#
# Cluster2
#
# Cluster2 Points:
# -----------------
# [[431811, 11059], [431811, 5980], [431811, 9101]]
# 3
# -----------------
#
# Cluster3
#
# Cluster3 Points:
# -----------------
# [[701787, 47528], [701787, 9101], [701787, 40458]]
# 3
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[497305, 56437], [497305, 18545], [497305, 40476]]
# 3
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[665714, 21244], [665714, 10843], [665714, 17014]]
# 3
# -----------------
#
# Cluster6
#
# Cluster6 Points:
# -----------------
# [[369049, 192496], [369049, 68496], [369049, 180037]]
# 3
# -----------------
#
# Cluster7
#
# Cluster7 Points:
# -----------------
# [[69450, 12563], [69450, 5980], [69450, 9101]]
# 3
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[656429, 4283], [656429, 302761], [656429, 144592]]
# 3
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[532699, 12563], [532699, 5980], [532699, 9101]]
# 3
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
# [[887491, 56437], [887491, 34525], [887491, 40476]]
# 3
# -----------------
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 16:40:47.193212
# run time 0:20:04.224827
#
# get tuple 3.490257263183594e-06
# recommend 0.05368509292602539
# eval_point 3.404617309570313e-05
# update 0.12038798060417176
# min:
# 30
# start time 2022-09-16 16:40:47.335231
# npmean(resuls[Recall@20]) 0.16666666666666666
# end time 2022-09-16 17:00:19.753629
# run time 0:19:32.418398
#
# get tuple 3.1839609146118164e-06
# recommend 0.03893399238586426
# eval_point 3.2842159271240234e-05
# update 0.11718801348209382

# %% [markdown]
# ## Iterations

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


it_array = [5,10,15,20,2.5,30]

num_clusters = 8
#cl_num_iterations = 5
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 200
num_iter = 9
learn_rate = 0.25
regularization = 0.45
eps = 0.1
MinPts = 20
k = 8
for it in it_array:
    print("it:")
    print(it)
    model = EDBSCAM_ICR(ImplicitData([],[]),  eps, MinPts, k, num_clusters, it, cl_learn_rate, cl_regularization,num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# it:
# 5
# start time 2022-09-16 18:28:29.869535
# npmean(resuls[Recall@20]) 0.14285714285714285
# end time 2022-09-16 18:49:06.218117
# run time 0:20:36.348582
#
# get tuple 3.897738456726074e-06
# recommend 0.047980036054338725
# eval_point 3.5064561026436945e-05
# update 0.12355880913734436
# it:
# 10
# start time 2022-09-16 18:49:06.372588
# npmean(resuls[Recall@20]) 0.16666666666666666
# end time 2022-09-16 19:10:00.325961
# run time 0:20:53.953373
#
# get tuple 3.9306640625e-06
# recommend 0.06371601422627766
# eval_point 4.279613494873047e-05
# update 0.12530983991622924
# it:
# 15
# start time 2022-09-16 19:10:00.479013
# npmean(resuls[Recall@20]) 0.15384615384615385
# end time 2022-09-16 19:30:49.565222
# run time 0:20:49.086209
#
# get tuple 4.1559457778930665e-06
# recommend 0.052159401086660534
# eval_point 4.0622857900766226e-05
# update 0.12483154125213623
# it:
# 20
# start time 2022-09-16 19:30:49.730516
# npmean(resuls[Recall@20]) 0.10526315789473684
# end time 2022-09-16 19:51:39.552151
# run time 0:20:49.821635
#
# get tuple 3.6820173263549805e-06
# recommend 0.05159027952896921
# eval_point 4.345492312782689e-05
# update 0.1248752248764038
# it:
# 2.5
# start time 2022-09-16 19:51:39.733690
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 20:12:08.802620
# run time 0:20:29.068930
#
# get tuple 3.41336727142334e-06
# recommend 0.03380351066589356
# eval_point 3.7169456481933595e-05
# update 0.12286518526077271
# it:
# 30
# start time 2022-09-16 20:12:09.001528
# npmean(resuls[Recall@20]) 0.1111111111111111
# end time 2022-09-16 20:33:02.702959
# run time 0:20:53.701431
#
# get tuple 4.146122932434082e-06
# recommend 0.048828442891438804
# eval_point 3.865030076768663e-05
# update 0.12531638600826264

# %% [markdown]
# ## Learning Rate

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


lr_array = [0.0001,0.001,0.01,0.1]

num_clusters = 8
cl_num_iterations = 10
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 200
num_iter = 9
regularization = 0.45
eps = 0.1
MinPts = 20
k = 8
for lr in lr_array:
    print("lr:")
    print(lr)
    model = EDBSCAM_ICR(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, lr, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# lr:
# 0.0001
# start time 2022-09-17 20:34:41.476297
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-17 20:55:17.045453
# run time 0:20:35.569156
#
# get tuple 3.684687614440918e-06
# recommend 0.0699129581451416
# eval_point 4.1103363037109376e-05
# update 0.12347822132110596
# lr:
# 0.001
# start time 2022-09-17 20:55:17.177379
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-17 21:15:05.259248
# run time 0:19:48.081869
#
# get tuple 3.1738042831420898e-06
# recommend 0.04177543520927429
# eval_point 3.993511199951172e-05
# update 0.1187671198129654
# lr:
# 0.01
# start time 2022-09-17 21:15:05.389597
# npmean(resuls[Recall@20]) 0.2222222222222222
# end time 2022-09-17 21:35:09.671870
# run time 0:20:04.282273
#
# get tuple 3.205704689025879e-06
# recommend 0.038907766342163086
# eval_point 3.650453355577257e-05
# update 0.1203856382369995
# lr:
# 0.1
# start time 2022-09-17 21:35:09.913916
# npmean(resuls[Recall@20]) 0.06666666666666667
# end time 2022-09-17 21:55:26.121993
# run time 0:20:16.208077
#
# get tuple 3.5717248916625977e-06
# recommend 0.05907023747762044
# eval_point 3.9736429850260414e-05
# update 0.12152417004108429

# %% [markdown]
# ## Regularization

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


re_array = [0,0.0001,0.001,0.01,0.1]

num_clusters = 8
cl_num_iterations = 10
cl_learn_rate =0.1
num_factors = 200
num_iter = 9
learn_rate = 0.25
regularization = 0.45
eps = 0.1
MinPts = 20
k = 8
for reg in re_array:
    print("reg:")
    print(reg)
    model = EDBSCAM_ICR(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, reg, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# reg:
# 0
# start time 2022-09-17 23:49:00.742148
# npmean(resuls[Recall@20]) 0.14285714285714285
# end time 2022-09-18 00:10:18.899585
# run time 0:21:18.157437
#
# get tuple 3.8711071014404295e-06
# recommend 0.05464509555271694
# eval_point 4.073551722935268e-05
# update 0.12776848149299622
# reg:
# 0.0001
# start time 2022-09-18 00:10:19.026994
# npmean(resuls[Recall@20]) 0.25
# end time 2022-09-18 00:31:31.871934
# run time 0:21:12.844940
#
# get tuple 3.558516502380371e-06
# recommend 0.04435962438583374
# eval_point 3.600120544433594e-05
# update 0.12725821261405945
# reg:
# 0.001
# start time 2022-09-18 00:31:32.012912
# npmean(resuls[Recall@20]) 0.1
# end time 2022-09-18 00:52:41.855037
# run time 0:21:09.842125
#
# get tuple 3.5970211029052734e-06
# recommend 0.06585114002227783
# eval_point 3.9625167846679685e-05
# update 0.12690987555980682
# reg:
# 0.01
# start time 2022-09-18 00:52:41.996562
# npmean(resuls[Recall@20]) 0.16666666666666666
# end time 2022-09-18 01:13:16.551185
# run time 0:20:34.554623
#
# get tuple 3.8122892379760743e-06
# recommend 0.04909976323445638
# eval_point 4.299481709798177e-05
# update 0.12341711509227753
# reg:
# 0.1
# start time 2022-09-18 01:13:16.690282
# npmean(resuls[Recall@20]) 0.15384615384615385
# end time 2022-09-18 01:33:40.591308
# run time 0:20:23.901026
#
# get tuple 3.88946533203125e-06
# recommend 0.053334712982177734
# eval_point 4.617984478290264e-05
# update 0.12231176013946533
