# %% [markdown]
# # ICE-DBSCAN Parameter Tunning ppf2

# %%
#imports
import numpy as np 
import csv
import pandas as pd
import re
import sys
import math
import matplotlib.pyplot as plt
from numpy import linalg as LA
import random
from sklearn.preprocessing import normalize
from numba import njit
from collections import defaultdict
import random
from implicit_data import ImplicitData
import numpy as np
from BISGD import BISGD
from ICE_DBSCAN import ICE_DBSCAN
from collections import defaultdict
from eval_implicit import EvalPrequential
from datetime import datetime
import getopt

# %% [markdown]
# ## Functions

# %%
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

def sumvector(V,x):
    result = []
    for v in V:
        temp = v + x
        result.append(temp)
    return result    

def multvector(x,V):
    result = []
    for v in V:
        temp = v * x
        result.append(temp)
    return result    

def TransformVec(V):
  
    #new = normalize(V[:,np.newaxis], axis=0).ravel()
    for i in range(len(V)):
        V[i] = sigmoid(V[i])
    D = LA.norm(V)
    D=1/D
    new = D * V
  

    return new

# %% [markdown]
# ## Get the data

# %%
sys.path.append('./')
configPath = 'config'
dataPath = 'ppf2_sample5_1.csv'

Data = []
data = pd.read_csv("ppf2_sample5_1.csv")
print(data)
Data = data.values.tolist()

Data = Data[1:]

#Data = []
#with open(dataPath, 'r') as f:
#    reader = csv.reader(f)
#    for row in reader:
#        Data.append([float(row[1]),float(row[2])])
Data = Data[:1000]
# Out:
#       Unnamed: 0     V1      V2
# 0             56    472   15116
# 1             57    472    4109
# 2             58    472    1697
# 3             59    472    6271
# 4            240    472   19237
# ...          ...    ...     ...
# 5889      111401  77607  107867
# 5890      111402  77607  103739
# 5891      111403  77607  103741
# 5892      111451  68410  103205
# 5893      111942  88921  104352
#
# [5894 rows x 3 columns]

# %% [markdown]
# # Parameter Study

# %% [markdown]
# ## Eps

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


eps_array = [0.1,0.25,0.5,0.75]
num_clusters = 8
cl_num_iterations = 5
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 90
num_iter = 8
learn_rate = 0.3
regularization = 0.4
#eps = 0.4
MinPts = 5
k = 8
for ep in eps_array:
    print("eps:")
    print(ep)
    model = ICE_DBSCAN(ImplicitData([],[]),  ep, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# eps:
# 0.1
# start time 2022-09-16 11:19:00.947210
# npmean(resuls[Recall@20]) 0.16666666666666666
# end time 2022-09-16 11:26:01.040639
# run time 0:07:00.093429
#
# get tuple 3.519273463724506e-06
# recommend 0.07504260540008545
# eval_point 3.639856974283854e-05
# update 0.07120242613231349
# eps:
# 0.25
# start time 2022-09-16 11:26:01.139662
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[8447, 20742], [8611, 17260], [81, 2167], [8733, 19673], [8733, 19674], [8447, 26465], [5350, 9035], [5350, 9036], [8673, 23481], [8724, 27025]]
# 10
# -----------------
#
# Cluster2
#
# Cluster2 Points:
# -----------------
# [[966, 14615], [8611, 17260], [5350, 9035], [5350, 9036], [8673, 23481], [8724, 27025], [8733, 19673], [8733, 19674], [81, 2167]]
# 9
# -----------------
#
# Cluster3
#
# Cluster3 Points:
# -----------------
# [[8760, 17584], [8611, 17260], [8673, 23481], [8733, 19673], [8733, 19674], [5350, 9035], [5350, 9036], [81, 2167], [8724, 27025]]
# 9
# -----------------
#
# Cluster4
#
# Cluster4 Points:
# -----------------
# [[8882, 12891], [8611, 17260], [8673, 23481], [8849, 3361], [8849, 1099], [81, 2167], [8733, 19673], [8733, 19674], [8760, 17584], [1616, 25163], [5350, 9035], [5350, 9036], [8724, 27025]]
# 13
# -----------------
#
# Cluster5
#
# Cluster5 Points:
# -----------------
[5047, 17264], [5047, 17260], [5047, 17262], [5047, 25120], [5047, 20819], [5047, 7146], [498, 28856], [498, 28857], [7441, 28857], [7441, 28856], [7441, 28855], [7532, 28857], [7532, 28856], [7532, 28855], [6169, 28856], [6169, 28857], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [9328, 27425], [9328, 27426], [9328, 9765], [9328, 9768], [9328, 9769], [9328, 16358], [8784, 9058], [8784, 9064], [8784, 9071], [8784, 9074], [8784, 9067]]
# 113
# -----------------
# npmean(resuls[Recall@20]) 0.16666666666666666
# end time 2022-09-16 11:33:18.789993
# run time 0:07:17.650331
#
# get tuple 3.2204916536676526e-06
# recommend 0.03298898537953695
# eval_point 3.914038340250651e-05
# update 0.07422483899931986
# eps:
# 0.5
# start time 2022-09-16 11:33:19.198348
#
# Cluster0
#
# Cluster0 Points:
# -----------------
# [[5350, 9035], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [8611, 17260], [6964, 13962], [6964, 8936], [6964, 20817]]
# 11
# -----------------
# npmean(resuls[Recall@20]) 0.125
# end time 2022-09-16 11:40:53.833213
# run time 0:07:34.634865
#
# get tuple 3.3158509937223585e-06
# recommend 0.03408527374267578
# eval_point 4.279613494873047e-05
# update 0.07709387723080234
# eps:
# 0.75
# start time 2022-09-16 11:40:54.597054
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 11:48:42.995183
# run time 0:07:48.398129
#
# get tuple 3.3083662767473393e-06
# recommend 0.02667280605861119
# eval_point 3.743171691894531e-05
# update 0.07944414276998232

# %% [markdown]
# ## MinPts

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


MinPts_array = [5,10,15,20,25,30]

num_clusters = 8
cl_num_iterations = 5
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 90
num_iter = 8
learn_rate = 0.3
regularization = 0.4
eps = 0.1
#MinPts = 5
k = 8
for min in MinPts_array:
    print("min:")
    print(min)
    model = ICE_DBSCAN(ImplicitData([],[]),  eps, min, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# min:
# 5
# start time 2022-09-16 14:57:59.367795
#
# Cluster0
#
# Cluster0 Points:
# -----------------
# [[5350, 9035], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [8611, 17260], [6964, 13962], [6964, 8936], [6964, 20817]]
# 11
# -----------------
# npmean(resuls[Recall@20]) 0.3333333333333333
# end time 2022-09-16 15:10:35.321106
# run time 0:12:35.953311
#
# get tuple 3.875950571031374e-06
# recommend 0.2663424809773763
# eval_point 4.784266153971354e-05
# update 0.1281356079639491
# min:
# 10
# start time 2022-09-16 15:10:36.116451
#
# Cluster0
#
# Cluster0 Points:
# -----------------
# [[81, 2167], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [8611, 17260], [5350, 9035], [5350, 9036], [6964, 13962], [6964, 8936], [6964, 20817], [6964, 7222]]
# 14
# -----------------
# npmean(resuls[Recall@20]) 0.2857142857142857
# end time 2022-09-16 15:18:50.840310
# run time 0:08:14.723859
#
# get tuple 3.7756149056365203e-06
# recommend 0.03272243908473423
# eval_point 3.705705915178571e-05
# update 0.08390340488672701
# min:
# 15
# start time 2022-09-16 15:18:51.633869
#
# Cluster0
#
# Cluster0 Points:
# -----------------
# [[8666, 22557], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [8611, 17260], [5350, 9035], [5350, 9036], [81, 2167], [5047, 17264], [5047, 17260], [5047, 17262], [5047, 25120], [5047, 20819], [5047, 7146], [8666, 9029], [8673, 23481], [8666, 13629], [6964, 13962], [6964, 8936], [6964, 20817], [6964, 7222], [6964, 1714], [6964, 8320], [6964, 20819], [6964, 20738], [6964, 8318], [6964, 13964], [6964, 13961]]
# 31
# -----------------
# npmean(resuls[Recall@20]) 0.16666666666666666
# end time 2022-09-16 15:26:54.591303
# run time 0:08:02.957434
#
# get tuple 3.492652146051194e-06
# recommend 0.015541831652323404
# eval_point 2.765655517578125e-05
# update 0.08193042722113282
# min:
# 20
# start time 2022-09-16 15:26:55.377044
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[8666, 22557], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [8611, 17260], [5350, 9035], [5350, 9036], [81, 2167], [5047, 17264], [5047, 17260], [5047, 17262], [5047, 25120], [5047, 20819], [5047, 7146], [8666, 9029], [8673, 23481], [8666, 13629], [6964, 13962], [6964, 8936], [6964, 20817], [6964, 7222], [6964, 1714], [6964, 8320], [6964, 20819], [6964, 20738], [6964, 8318], [6964, 13964], [6964, 13961]]
# 31
# -----------------
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 15:34:45.723595
# run time 0:07:50.346551
#
# get tuple 3.3703478248864183e-06
# recommend 0.02364492416381836
# eval_point 3.4968058268229164e-05
# update 0.07979429935369228
# min:
# 25
# start time 2022-09-16 15:34:46.507264
#
# Cluster0
#
# Cluster0 Points:
# -----------------
# [[5047, 25120], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [6964, 13962], [6964, 8936], [6964, 20817], [6964, 7222], [6964, 1714], [6964, 8320], [6964, 20819], [6964, 20738], [6964, 8318], [6964, 13964], [6964, 13961], [8611, 17260], [5350, 9035], [5350, 9036], [81, 2167], [5047, 17264], [5047, 17260], [5047, 17262]]
# 25
# -----------------
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[8666, 21417], [472, 4109], [472, 1697], [472, 6271], [472, 19237], [472, 11784], [472, 14152], [6964, 13962], [6964, 8936], [6964, 20817], [6964, 7222], [6964, 1714], [6964, 8320], [6964, 20819], [6964, 20738], [6964, 8318], [6964, 13964], [6964, 13961], [8611, 17260], [5350, 9035], [5350, 9036], [81, 2167], [5047, 17264], [5047, 17260], [5047, 17262], [5047, 25120], [5047, 20819], [5047, 7146], [8666, 9029], [8673, 23481], [8666, 13629], [8666, 22557]]
# 32
# -----------------
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 15:42:43.112842
# run time 0:07:56.605578
#
# get tuple 3.5859481316965707e-06
# recommend 0.030116478602091473
# eval_point 3.4968058268229164e-05
# update 0.0808528741227737
# min:
# 30
# start time 2022-09-16 15:42:43.960558
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 15:50:34.640674
# run time 0:07:50.680116
#
# get tuple 3.4801506458064323e-06
# recommend 0.03536384446280343
# eval_point 3.7091118948800226e-05
# update 0.07982056775684573

# %% [markdown]
# ## Iterations

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


Iterations_array = [5,10,15,20,25,30]

num_clusters = 8
#cl_num_iterations = 5
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 90
num_iter = 8
learn_rate = 0.3
regularization = 0.4
eps = 0.1
MinPts = 5
k = 8
for it in Iterations_array:
    print("it:")
    print(it)
    model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, it, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# it:
# 5
# start time 2022-09-16 18:24:27.310745
# npmean(resuls[Recall@20]) 0.2
# end time 2022-09-16 18:31:30.984421
# run time 0:07:03.673676
#
# get tuple 3.502766628449869e-06
# recommend 0.05091733932495117
# eval_point 4.124641418457031e-05
# update 0.07184292637753645
# it:
# 10
# start time 2022-09-16 18:31:31.060135
# npmean(resuls[Recall@20]) 0.2727272727272727
# end time 2022-09-16 18:38:26.540087
# run time 0:06:55.479952
#
# get tuple 3.1786581544667336e-06
# recommend 0.03184700012207031
# eval_point 4.118139093572443e-05
# update 0.07043733852495873
# it:
# 15
# start time 2022-09-16 18:38:26.609333
# npmean(resuls[Recall@20]) 0.25
# end time 2022-09-16 18:45:18.464554
# run time 0:06:51.855221
#
# get tuple 2.855116091497924e-06
# recommend 0.017835557460784912
# eval_point 3.695487976074219e-05
# update 0.06986834625426687
# it:
# 20
# start time 2022-09-16 18:45:18.537953
# npmean(resuls[Recall@20]) 0.09090909090909091
# end time 2022-09-16 18:52:11.242809
# run time 0:06:52.704856
#
# get tuple 3.781076726131805e-06
# recommend 0.03253431753678755
# eval_point 3.418055447665128e-05
# update 0.06996455112459217
# it:
# 25
# start time 2022-09-16 18:52:11.306665
# npmean(resuls[Recall@20]) 0.2
# end time 2022-09-16 18:59:00.122203
# run time 0:06:48.815538
#
# get tuple 2.786094863609367e-06
# recommend 0.030257701873779297
# eval_point 4.15802001953125e-05
# update 0.06934051705442461
# it:
# 30
# start time 2022-09-16 18:59:00.188129
# npmean(resuls[Recall@20]) 0.1111111111111111
# end time 2022-09-16 19:05:55.069428
# run time 0:06:54.881299
#
# get tuple 3.1685841299976536e-06
# recommend 0.017247464921739366
# eval_point 2.5643242730034723e-05
# update 0.0703685178874851

# %% [markdown]
# ## Learning Rate

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


lr_array = [0.0001,0.001,0.01,0.1]

num_clusters = 8
cl_num_iterations = 10
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 90
num_iter = 8
learn_rate = 0.3
regularization = 0.4
eps = 0.1
MinPts = 5
k = 8
for lr in lr_array:
    print("lr:")
    print(lr)
    model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, lr, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# lr:
# 0.0001
# start time 2022-09-16 19:06:59.391299
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 19:13:52.037563
# run time 0:06:52.646264
#
# get tuple 3.3648050885319445e-06
# recommend 0.05123782157897949
# eval_point 3.62396240234375e-05
# update 0.07000690814940205
# lr:
# 0.001
# start time 2022-09-16 19:13:52.120286
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 19:20:40.724583
# run time 0:06:48.604297
#
# get tuple 3.0462798088328777e-06
# recommend 0.020678599675496418
# eval_point 2.1378199259440105e-05
# update 0.06931959524758295
# lr:
# 0.01
# start time 2022-09-16 19:20:40.797742
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 19:27:28.062377
# run time 0:06:47.264635
#
# get tuple 2.865594695262951e-06
# recommend 0.02969523270924886
# eval_point 3.3060709635416664e-05
# update 0.06907310057794949
# lr:
# 0.1
# start time 2022-09-16 19:27:28.143039
# npmean(resuls[Recall@20]) 0.5
# end time 2022-09-16 19:34:19.721259
# run time 0:06:51.578220
#
# get tuple 2.87109697368783e-06
# recommend 0.03919994831085205
# eval_point 4.9114227294921875e-05
# update 0.06982218638636474

# %% [markdown]
# ## Regularization

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


reg_array = [0,0.0001,0.001,0.01,0.1]

num_clusters = 8
cl_num_iterations = 10
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 90
num_iter = 8
learn_rate = 0.3
regularization = 0.4
eps = 0.1
MinPts = 5
k = 8
for reg in reg_array:
    print("reg:")
    print(reg)
    model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, reg, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
    eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
    start_recommend = datetime.now()
    print('start time', start_recommend)

    results=eval.EvaluateTime(0,stream.size, 100)

    print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
    end_recommend = datetime.now()
    print('end time', end_recommend)

    tempo = end_recommend - start_recommend

    print('run time', tempo)
    print('')
    print('get tuple',np.mean(results['time_get_tuple']))
    print('recommend',np.mean(results['time_recommend']))
    print('eval_point',np.mean(results['time_eval_point']))
    print('update',np.mean(results['time_update']))
# Out:
# reg:
# 0
# start time 2022-09-16 23:18:48.817688
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 23:26:01.921026
# run time 0:07:13.103338
#
# get tuple 3.198361166179352e-06
# recommend 0.029636661211649578
# eval_point 4.2597452799479164e-05
# update 0.07345699305124119
# reg:
# 0.0001
# start time 2022-09-16 23:26:02.002603
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-16 23:33:33.956802
# run time 0:07:31.954199
#
# get tuple 3.9673045760562055e-06
# recommend 0.03630031858171735
# eval_point 4.444803510393415e-05
# update 0.07664178847133779
# reg:
# 0.001
# start time 2022-09-16 23:33:34.034605
# npmean(resuls[Recall@20]) 0.25
# end time 2022-09-16 23:40:49.702574
# run time 0:07:15.667969
#
# get tuple 3.3841035209486163e-06
# recommend 0.02922886610031128
# eval_point 4.571676254272461e-05
# update 0.07390136911329745
# reg:
# 0.01
# start time 2022-09-16 23:40:49.863396
# npmean(resuls[Recall@20]) 0.1
# end time 2022-09-16 23:47:59.121808
# run time 0:07:09.258412
#
# get tuple 3.2592503502193743e-06
# recommend 0.02547190189361572
# eval_point 4.088878631591797e-05
# update 0.07279029002562658
# reg:
# 0.1
# start time 2022-09-16 23:47:59.232399
# npmean(resuls[Recall@20]) 0.42857142857142855
# end time 2022-09-16 23:55:21.067726
# run time 0:07:21.835327
#
# get tuple 3.3516158034840726e-06
# recommend 0.030576297215053012
# eval_point 4.1178294590541297e-05
# update 0.07493271067897836
