# %% [markdown]
# # ICE-DBSCAN Evaluation ml1m

# %%
#imports
import numpy as np 
import csv
import pandas as pd
import re
import sys
import math
import matplotlib.pyplot as plt
from numpy import linalg as LA
import random
from sklearn.preprocessing import normalize
from numba import njit
from collections import defaultdict
import random
from implicit_data import ImplicitData
import numpy as np
from BISGD import BISGD
from ICE_DBSCAN import ICE_DBSCAN
from collections import defaultdict
from eval_implicit import EvalPrequential
from datetime import datetime
import getopt

# %% [markdown]
# ## Functions

# %%
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

def sumvector(V,x):
    result = []
    for v in V:
        temp = v + x
        result.append(temp)
    return result    

def multvector(x,V):
    result = []
    for v in V:
        temp = v * x
        result.append(temp)
    return result    

def TransformVec(V):
  
    #new = normalize(V[:,np.newaxis], axis=0).ravel()
    for i in range(len(V)):
        V[i] = sigmoid(V[i])
    D = LA.norm(V)
    D=1/D
    new = D * V
  

    return new

# %% [markdown]
# ## Get the data

# %%
sys.path.append('./')
configPath = 'config'

Data = []
data = pd.read_csv("ml1m_sample5_1.csv")
print(data)
Data = data.values.tolist()

Data = Data[1:]
Data = Data[:10000]
# Out:
#        Unnamed: 0  UserID  ItemID   Timestamp
# 0             365    6029     899   956721639
# 1             366    6029    3548   956721700
# 2             367    6029    3545   956721732
# 3             368    6029    3543   956721759
# 4             369    6029    3549   956721780
# ...           ...     ...     ...         ...
# 11252      225903     937    2300  1042909231
# 11253      225935     195    3746  1043562457
# 11254      226240    4312     750  1045841700
# 11255      226241    4312    1267  1045841716
# 11256      226267     911    2409  1046066544
#
# [11257 rows x 4 columns]

# %% [markdown]
# ## Sampled datasets

# %% [markdown]
# ### ml1m_sample5_1

# %%
sys.path.append('./')
configPath = 'config'

Data = []
data = pd.read_csv("ml1m_sample5_1.csv")
print(data)
Data = data.values.tolist()

Data = Data[1:]
 
Data = Data[:10000]
# Out:
#        Unnamed: 0  UserID  ItemID   Timestamp
# 0             365    6029     899   956721639
# 1             366    6029    3548   956721700
# 2             367    6029    3545   956721732
# 3             368    6029    3543   956721759
# 4             369    6029    3549   956721780
# ...           ...     ...     ...         ...
# 11252      225903     937    2300  1042909231
# 11253      225935     195    3746  1043562457
# 11254      226240    4312     750  1045841700
# 11255      226241    4312    1267  1045841716
# 11256      226267     911    2409  1046066544
#
# [11257 rows x 4 columns]

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


num_clusters = 8
cl_num_iterations = 20
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 160
num_iter = 8
learn_rate = 0.1
regularization = 0.4
eps = 0.75
MinPts = 20
k = 8
model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
start_recommend = datetime.now()
print('start time', start_recommend)

results=eval.EvaluateTime(0,stream.size, 100)

print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
end_recommend = datetime.now()
print('end time', end_recommend)

tempo = end_recommend - start_recommend

print('run time', tempo)
print('')
print('get tuple',np.mean(results['time_get_tuple']))
print('recommend',np.mean(results['time_recommend']))
print('eval_point',np.mean(results['time_eval_point']))
print('update',np.mean(results['time_update']))
# Out:
# start time 2022-09-24 17:06:11.318726
# npmean(resuls[Recall@20]) 0.08181818181818182
# end time 2022-09-24 17:29:32.435587
# run time 0:23:21.116861
#
# get tuple 4.280567169189453e-06
# recommend 0.022885162180120294
# eval_point 5.539764057506214e-05
# update 0.13984818441867827

# %% [markdown]
# ### ml1m_sample5_2

# %%
sys.path.append('./')
configPath = 'config'

Data = []
data = pd.read_csv("ml1m_sample5_2.csv")
print(data)
Data = data.values.tolist()

Data = Data[1:]
# Out:
#        UserID  ItemID   Timestamp
# 0        5984     260   956907731
# 1        5984     111   956907754
# 2        5984    2146   956907772
# 3        5984     541   956907856
# 4        5984    3471   956907857
# ...       ...     ...         ...
# 11409    5329    1212  1045895993
# 11410    5329    2692  1045896006
# 11411    5329     942  1045896053
# 11412    5329    2019  1045896053
# 11413    5329    3035  1045896063
#
# [11414 rows x 3 columns]

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


num_clusters = 8
cl_num_iterations = 20
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 160
num_iter = 8
learn_rate = 0.1
regularization = 0.4
eps = 0.75
MinPts = 20
k = 8
model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
start_recommend = datetime.now()
print('start time', start_recommend)

results=eval.EvaluateTime(0,stream.size, 100)

print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
end_recommend = datetime.now()
print('end time', end_recommend)

tempo = end_recommend - start_recommend

print('run time', tempo)
print('')
print('get tuple',np.mean(results['time_get_tuple']))
print('recommend',np.mean(results['time_recommend']))
print('eval_point',np.mean(results['time_eval_point']))
print('update',np.mean(results['time_update']))
# Out:
# start time 2022-09-24 17:34:09.148853
# npmean(resuls[Recall@20]) 0.0
# end time 2022-09-24 18:06:27.370062
# run time 0:32:18.221209
#
# get tuple 5.168855467070771e-06
# recommend 0.06630831440602701
# eval_point 6.1018260445181776e-05
# update 0.16907305651873383

# %% [markdown]
# ### ml1m_sample5_3

# %%
sys.path.append('./')
configPath = 'config'

Data = []
data = pd.read_csv("ml1m_sample5_3.csv")
print(data)
Data = data.values.tolist()

Data = Data[1:]
# Out:
#        Unnamed: 0  UserID  ItemID   Timestamp
# 0             110    6035    1193   956710879
# 1             120    6035    2628   956711024
# 2             123    6035    3175   956711064
# 3             124    6035    2571   956711064
# 4             129    6035    1527   956711121
# ...           ...     ...     ...         ...
# 11544      226173    5654    1500  1045160087
# 11545      226174    5654      39  1045160173
# 11546      226175    5654    3358  1045160206
# 11547      226176    5654    3526  1045162240
# 11548      226203    5654    2022  1045669508
#
# [11549 rows x 4 columns]

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


num_clusters = 8
cl_num_iterations = 20
cl_learn_rate =0.1
cl_regularization = 0.1
num_factors = 160
num_iter = 8
learn_rate = 0.1
regularization = 0.4
eps = 0.75
MinPts = 20
k = 8
model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
start_recommend = datetime.now()
print('start time', start_recommend)

results=eval.EvaluateTime(0,stream.size, 100)

print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
end_recommend = datetime.now()
print('end time', end_recommend)

tempo = end_recommend - start_recommend

print('run time', tempo)
print('')
print('get tuple',np.mean(results['time_get_tuple']))
print('recommend',np.mean(results['time_recommend']))
print('eval_point',np.mean(results['time_eval_point']))
print('update',np.mean(results['time_update']))
# Out:
# start time 2022-09-24 18:06:35.166747
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[5648, 1307], [5870, 1060], [5870, 2997], [5870, 1884], [5870, 2395], [5870, 2501], [5870, 2571], [5870, 1222], [5870, 2858], [5870, 1288], [5870, 1206], [5870, 608], [5870, 296], [5870, 318], [5870, 1732], [5870, 1258], [5870, 260], [5870, 1291], [5870, 1270], [5772, 2944], [5648, 3448], [5648, 588], [5648, 3114], [6006, 2575], [6006, 1271], [6006, 3247], [6006, 2692], [6006, 3418], [6006, 2908], [6006, 2161], [6006, 919], [6006, 1028], [6006, 2097], [6006, 2037], [5872, 912], [5872, 2571], [5872, 318], [5872, 2858], [5872, 2357], [5872, 1777], [5872, 104], [5872, 1275], [5872, 1358], [5872, 920], [5872, 2329], [5872, 249], [5872, 2686], [5872, 2826], [5872, 2997], [5872, 2762], [5875, 593], [5875, 260], [5875, 1196], [5875, 1198], [5875, 858], [5875, 110], [5875, 1214], [5875, 1240], [5875, 1176], [5875, 318], [5875, 50], [5913, 1270], [5913, 356], [5913, 608], [5913, 318], [5913, 593], [5913, 50], [5913, 1213], [5913, 1617], [5913, 527], [5913, 34], [5913, 1089], [5913, 1673], [5913, 47], [5913, 110], [5913, 595], [5913, 2282], [5913, 529], [5913, 428], [5913, 1721], [5913, 588], [5913, 362], [5913, 3147], [5913, 597], [5913, 555], [5913, 293], [5913, 456], [5887, 2797], [5887, 1188], [5887, 1265], [5887, 318], [5887, 858], [5887, 1247], [5887, 924], [5887, 17], [5887, 920], [5887, 899], [5887, 1947], [5887, 1035], [5887, 1097], [5875, 2858], [5875, 3408], [5875, 2396], [5875, 1617], [5875, 589], [5875, 1221], [5875, 2115], [5875, 2571], [5875, 1527], [5875, 1275], [5875, 2023], [5875, 70], [5875, 1690], [5974, 1617], [5974, 3435], [5974, 923], [5974, 1252], [5974, 903], [5974, 912], [5974, 1204], [5974, 111], [5974, 899], [5974, 919], [5974, 306], [5974, 527], [5974, 3362], [5974, 930], [5974, 1248], [5974, 1267], [5974, 942], [5974, 1179], [5974, 858], [5974, 296], [5974, 608], [5974, 2692], [5974, 2194], [5974, 2917], [5974, 1912], [5974,
, 3307], [5875, 2728], [5875, 1084], [5875, 1960], [5875, 32], [5875, 1320], [5875, 1173], [5887, 2797], [5887, 1188], [5887, 1265], [5887, 318], [5887, 858], [5887, 1247], [5887, 924], [5887, 17], [5887, 920], [5887, 899], [5887, 1947], [5887, 1035], [5887, 1097], [6006, 2575], [6006, 1271], [6006, 3247], [6006, 2692], [6006, 3418], [6006, 2908], [6006, 2161], [6006, 919], [6006, 1028], [6006, 2097], [6006, 2037], [5913, 1270], [5913, 356], [5913, 608], [5913, 318], [5913, 593], [5913, 50], [5913, 1213], [5913, 1617], [5913, 527], [5913, 34], [5913, 1089], [5913, 1673], [5913, 47], [5913, 110], [5913, 595], [5913, 2282], [5913, 529], [5913, 428], [5913, 1721], [5913, 588], [5913, 362], [5913, 3147], [5913, 597], [5913, 555], [5913, 293], [5913, 456], [6006, 2562], [6006, 916], [5870, 1060], [5870, 2997], [5870, 1884], [5870, 2395], [5870, 2501], [5870, 2571], [5870, 1222], [5870, 2858], [5870, 1288], [5870, 1206], [5870, 608], [5870, 296], [5870, 318], [5870, 1732], [5870, 1258], [5870, 260], [5870, 1291], [5870, 1270], [5849, 1291], [5849, 2961], [5849, 2997], [5849, 2628], [5849, 1196], [5849, 1204], [5849, 527], [5849, 2028], [5849, 1224], [5849, 2427], [5849, 1408], [5849, 260], [5849, 750], [5849, 720], [5849, 745], [5849, 541], [5849, 2804], [5849, 1198], [5849, 34], [5849, 2384], [5849, 1148], [5849, 1223], [5765, 2028], [5765, 924], [5765 ...
# 1037
# -----------------
# npmean(resuls[Recall@20]) 0.11702127659574468
# end time 2022-09-24 18:37:24.334085
# run time 0:30:49.167338
#
# get tuple 4.054726223075187e-06
# recommend 0.021665507174552755
# eval_point 5.330684337210148e-05
# update 0.15994111588144122

# %% [markdown]
# ### ml1m_sample5_4

# %%
sys.path.append('./')
configPath = 'config'

Data = []
data = pd.read_csv("ml1m_sample5_4.csv")
print(data)
Data = data.values.tolist()

Data = Data[1:]
# Out:
#        Unnamed: 0  UserID  ItemID   Timestamp
# 0              42    6038    1079   956707547
# 1              43    6038    1148   956707604
# 2              44    6038    3088   956707640
# 3              45    6038    1223   956707734
# 4             206    6033    1193   956713500
# ...           ...     ...     ...         ...
# 11461      226168    4958    2087  1045000073
# 11462      226242     839     909  1045857499
# 11463      226243     839     750  1045857818
# 11464      226244     839     954  1045859395
# 11465      226310    4958    1407  1046454443
#
# [11466 rows x 4 columns]

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


num_clusters = 8
cl_num_iterations = 20
cl_learn_rate =0.1
cl_regularization = 0.001
num_factors = 160
num_iter = 8
learn_rate = 0.1
regularization = 0.4
eps = 0.75
MinPts = 20
k = 8
model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
start_recommend = datetime.now()
print('start time', start_recommend)

results=eval.EvaluateTime(0,stream.size, 100)

197], [5765, 1198], [5765, 1215], [5765, 2115], [5765, 3265], [5765, 1036], [5765, 1218], [5765, 1222], [5765, 2414], [5765, 2273], [5765, 318], [5765, 1148], [5765, 1213], [5765, 745], [5765, 1258], [5765, 2762], [5765, 1136], [5765, 2788], [5765, 1080], [5765, 1223], [5765, 1079], [5765, 3147], [6033, 1193], [6033, 1214], [6033, 2028], [6033, 110], [6033, 1036], [6033, 457], [6033, 1408], [6033, 3404], [6033, 480], [6033, 349], [6033, 1608], [6033, 2353], [6033, 380], [6033, 1580], [5732, 1197], [5732, 260], [5732, 1198], [5732, 1291], [5732, 1374], [5732, 590], [5732, 969], [5732, 912], [5732, 2396], [5732, 497], [5710, 527], [5710, 2858], [5710, 2762], [5710, 2329], [5710, 265], [5710, 58], [5710, 2028], [5710, 475], [5710, 2959], [5710, 1693], [5710, 50], [5710, 1617], [5710, 745], [5710, 1214], [5710, 1653], [5983, 1968], [5983, 110], [5983, 1373], [5983, 3354], [5983, 1196], [5983, 1097], [5983, 924], [5983, 2529], [5983, 2140], [5983, 1200], [5983, 1127], [5983, 2657], [5751, 2572], [5751, 2706], [5751, 2683], [5751, 2694], [5751, 2759], [5751, 2718], [5751, 3159], [5751, 2581], [5751, 2574], [5751, 2485], [5751, 1513], [5751, 2700], [5751, 3114], [5751, 1], [5907, 2186], [5907, 908], [5907, 3548], [5907, 3163], [5907, 904], [5907, 750], [5907, 1212], [5907, 965], [5907, 2208], [5907, 1267], [5907, 1299], [5907, 1199], [5907, 929], [5907, 2599], [5907, 1304], [5902, 356], [5902, 527], [5902, 1684], [5902, 1230], [5902, 2927], [5902, 3606], [5902, 412], [5902, 515], [5902, 1303], [5726, 953], [5726, 858], [5726, 1204], [5726, 1233], [5726, 1250], [5726, 527], [5726 ...
# 1064
# -----------------
# npmean(resuls[Recall@20]) 0.05504587155963303
# end time 2022-09-24 19:07:49.983773
# run time 0:30:21.306679
#
# get tuple 4.2968372356616096e-06
# recommend 0.024283072270384624
# eval_point 6.579477852637615e-05
# update 0.15861388338324392

# %% [markdown]
# ### ml1m_sample5_5

# %%
sys.path.append('./')
configPath = 'config'

Data = []
data = pd.read_csv("ml1m_sample5_5.csv")
print(data)
Data = data.values.tolist()

Data = Data[1:]
# Out:
#        Unnamed: 0  UserID  ItemID   Timestamp
# 0               1    6040     593   956703954
# 1               2    6040    2019   956703977
# 2               3    6040     213   956704056
# 3               4    6040    3111   956704056
# 4               5    6040     912   956704191
# ...           ...     ...     ...         ...
# 11050      226029     424    1935  1043844911
# 11051      226054     424    1939  1044296801
# 11052      226201     424    3739  1045581875
# 11053      226239     424    2494  1045837566
# 11054      226279     424    3535  1046112575
#
# [11055 rows x 4 columns]

# %%
Data_Transpose = np.transpose(Data)
stream = ImplicitData(Data_Transpose[1],Data_Transpose[2])


num_clusters = 8
cl_num_iterations = 20
cl_learn_rate =0.1
cl_regularization = 0.001
num_factors = 160
num_iter = 8
learn_rate = 0.1
regularization = 0.4
eps = 0.75
MinPts = 20
k = 8
model = ICE_DBSCAN(ImplicitData([],[]),  eps, MinPts, k, num_clusters, cl_num_iterations, cl_learn_rate, cl_regularization, 
        num_factors, num_iter, learn_rate, regularization, random_seed = 10)
eval = EvalPrequential(model,stream, metrics = ["Recall@20"])
start_recommend = datetime.now()
print('start time', start_recommend)

results=eval.EvaluateTime(0,stream.size, 100)

print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
end_recommend = datetime.now()
print('end time', end_recommend)

tempo = end_recommend - start_recommend

print('run time', tempo)
print('')
print('get tuple',np.mean(results['time_get_tuple']))
print('recommend',np.mean(results['time_recommend']))
print('eval_point',np.mean(results['time_eval_point']))
print('update',np.mean(results['time_update']))
# Out:
# start time 2022-09-24 19:07:54.147299
#
# Cluster1
#
# Cluster1 Points:
# -----------------
# [[5898, 2580], [5999, 922], [5999, 3435], [5999, 1248], [5999, 1252], [5999, 1260], [5999, 1267], [5999, 2066], [5999, 2186], [5999, 1069], [5999, 541], [5999, 942], [5999, 2940], [5999, 746], [5988, 1079], [5988, 1719], [5988, 2858], [5988, 2324], [5988, 36], [5898, 3072], [5898, 50], [5877, 1257], [5877, 2628], [5877, 1196], [5877, 2716], [5877, 2762], [5877, 2700], [5737, 527], [5737, 593], [5737, 913], [5737, 1096], [5737, 608], [5737, 750], [5737, 1537], [5737, 924], [5737, 47], [5697, 1198], [5697, 1721], [5697, 2021], [5697, 3555], [5697, 3513], [5697, 3565], [5697, 3578], [5697, 2628], [5697, 3360], [5697, 2762], [5697, 2861], [5697, 3082], [5693, 1230], [5693, 111], [5693, 913], [5693, 1284], [5693, 923], [5693, 912], [5693, 2731], [5693, 3089], [5693, 2360], [5693, 2289], [5693, 123], [5737, 2150], [5737, 1965], [5737, 2791], [5737, 2324], [5632, 527], [5632, 2908], [5632, 1097], [5632, 2028], [5632, 2571], [5632, 1912], [5632, 1527], [5632, 1610], [5632, 1408], [5632, 2858], [5632, 912], [5632, 2336], [5631, 3101], [5631, 3176], [5631, 1968], [5631, 306], [5631, 318], [5631, 308], [5839, 678], [5839, 2028], [5839, 527], [5839, 2297], [5839, 2023], [5839, 318], [5839, 1221], [5839, 1198], [5839, 110], [5839, 293], [5839, 2918], [5839, 2948], [5839, 1265], [5839, 1], [5839, 1278], [5839, 1284], [5839, 913], [5839, 949], [5839, 953], [5825, 1196], [5825, 296], [5825, 593], [5825, 3418], [5825, 2997], [5825, 223], [5825, 2355], [5825, 2318], [5825, 3160], [5825, 2692], [5825, 2396], [5825, 2762], [5825, 3114], [5825, 1428], [5825, 318], [5825, 1193], [5825, 50], [5825, 745], [5825, 556], [5825, 1111], [5825, 1089], [5825, 2571], [5825, 1], [5825, 1673], [5825, 1641], [5825, 1921], [5825, 2329], [6026, 924], [6026, 260], [6026, 750], [6026, 541], [6026, 1196], [6026, 1206], [6026, 1199], [6026, 1210], [6026, 1077], [6026, 1097], [6026, 2628], [6026, 2407], [6026, 162], [6026, 923], [6026, 1225], [6026, 1233]]
# 143
# -----------------
# npmean(resuls[Recall@20]) 0.12
# end time 2022-09-24 19:36:42.114735
# run time 0:28:47.967436
#
# get tuple 4.865516260905272e-06
# recommend 0.02341904640197754
# eval_point 5.415916442871094e-05
# update 0.15604121121657957
